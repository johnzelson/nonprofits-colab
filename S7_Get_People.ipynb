# %% [markdown]
# <a href="https://colab.research.google.com/github/johnzelson/local-nonprofit-colab/blob/main/S7_Get_People.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Overview
#
# Step Seven (S7 Get People)
#
# This notebook gets the list of People included in IRS Business Master File as ICO (In Care Of) and the Officers and trusted Staff (eg. Director) listed in latest Tax Return.
#
# The list of people and affiliations is creates a fun way to show affiliation and interconnection - Potential collaborators?
#
# For example, is there a similar group of people active in Arts-related programs?

# %% [markdown]
# # Tech Notes
#
#
# In:  np_local_df
#
# Out:  all_people_df
#
#
# IRS Tax data is provided in XML files.  During processing, XML sections on people were dumped into dataframe.  The people xml snippet gets massaged into json, flattened, and written to a people dataframe - one row for each person and affiliation.  TODO: should use xmltodict on these snippets, instead of the simple-minded tweaks to format XML for json (eg. valid json has double quotes; names like O'Connell...)

# %% [markdown]
# # Setup

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import requests
import pprint
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
import folium
from google.colab import userdata
import pprint
import json
import numpy as np
import re

pd.set_option('display.max_columns', 100);
pd.set_option('display.max_rows', 100);

proc_dir = '/content/drive/My Drive/IRS_processed/'
data_dir = '/content/drive/My Drive/irs_data/'

# %%
# get np local df


dtype = {"CLASSIFICATION": str,
         "EIN" : str,
         "ACTIVITY" : str,
         "AFFILIATION" : str,
         "ORGANIZATION" : str,
         "FOUNDATION" : str,
         "NTEE_CD" : str,
         "RULING" : str,
         "ZIP" : str,
         "TAX_PERIOD" : str,
         "GROUP" : str
         }

np_local_df = pd.read_csv('/content/drive/My Drive/IRS_processed/np_local_df.csv',
                          dtype=dtype)

display(np_local_df)

# %%
np_local_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 121 columns):
#  #    Column                        Dtype
# ---   ------                        -----
#  0    EIN                           int64
#  1    NAME                          object
#  2    ICO                           object
#  3    STREET                        object
#  4    CITY                          object
#  5    STATE                         object
#  6    ZIP                           object
#  7    GROUP                         int64
#  8    SUBSECTION                    int64
#  9    AFFILIATION                   int64
#  10   CLASSIFICATION                int64
#  11   RULING                        int64
#  12   DEDUCTIBILITY                 int64
#  13   FOUNDATION                    int64
#  14   ACTIVITY                      int64
#  15   ORGANIZATION                  int64
#  16   STATUS                        int64
#  17   TAX_PERIOD                    float64
#  18   ASSET_CD                      int64
#  19   INCOME_CD                     int64
#  20   FILING_REQ_CD                 int64
#  21   PF_FILING_REQ_CD              int64
#  22   ACCT_PD                       int64
#  23   ASSET_AMT                     float64
#  24   INCOME_AMT                    float64
#  25   REVENUE_AMT                   float64
#  26   NTEE_CD                       object
#  27   SORT_NAME                     object
#  28   p_org_id                      int64
#  29   ntee_cat                      object
#  30   ntee_define                   object
#  31   CLASS1                        int64
#  32   CLASS2                        int64
#  33   CLASS3                        int64
#  34   CLASS4                        int64
#  35   ACT1                          int64
#  36   ACT2                          int64
#  37   ACT3                          int64
#  38   act1_lu                       object
#  39   act2_lu                       object
#  40   act3_lu                       object
#  41   RULE_DT                       object
#  42   aff_lu                        object
#  43   org_lu                        object
#  44   found_lu                      object
#  45   filename                      object
#  46   IRS_Form                      object
#  47   TaxPeriodEndDt                object
#  48   TaxPeriodBeginDt              object
#  49   TaxYr                         float64
#  50   ReturnTypeCd                  object
#  51   PhoneNum                      object
#  52   BusinessNameLine1Txt          object
#  53   AddressLine1Txt               object
#  54   AddressLine2Txt               object
#  55   CityNm                        object
#  56   StateAbbreviationCd           object
#  57   ZIPCd                         float64
#  58   CountryCd                     object
#  59   ProvinceOrStateNm             object
#  60   ForeignPostalCd               object
#  61   WebsiteAddressTxt             object
#  62   TypeOfOrganizationCorpInd     object
#  63   TotalRevenueAmt               object
#  64   ProgramSrvcAccomplishmentGrp  object
#  65   LegalDomicileStateCd          object
#  66   LegalDomicileCountryCd        object
#  67   GroupReturnForAffiliatesInd   object
#  68   Organization501c3Ind          object
#  69   TotalExpensesAmt              object
#  70   Pgm_Serv_Accomps              object
#  71   Total_Revenue                 object
#  72   Mission                       object
#  73   people                        object
#  74   FormationYr                   object
#  75   ActivityOrMissionDesc         object
#  76   TotalEmployeeCnt              object
#  77   MissionDesc                   object
#  78   CYTotalRevenueAmt             object
#  79   Desc                          object
#  80   status                        object
#  81   coord_x                       float64
#  82   coord_y                       float64
#  83   cb_BASENAME                   float64
#  84   cb_BLKGRP                     float64
#  85   cb_BLOCK                      float64
#  86   cb_GEOID                      float64
#  87   cb_NAME                       object
#  88   cb_TRACT                      float64
#  89   cb_COUNTY                     float64
#  90   cb_STATE                      float64
#  91   cnty_COUNTY                   float64
#  92   cnty_NAME                     object
#  93   cnty_STATE                    float64
#  94   cong_BASENAME                 float64
#  95   cong_NAME                     object
#  96   cntysub_NAME                  object
#  97   cntysub_COUSUB                float64
#  98   cntysub_GEOID                 float64
#  99   inc_PLACE                     float64
#  100  centracts_NAME                object
#  101  centracts_TRACT               float64
#  102  csa_NAME                      object
#  103  csa_GEOID                     float64
#  104  legup_NAME                    object
#  105  leglow_NAME                   object
#  106  num_matches                   float64
#  107  cntysub_PLACE                 object
#  108  congress_rep_link             object
#  109  state_leg_lower_link          object
#  110  state_leg_upper_link          object
#  111  Unnamed: 0                    float64
#  112  url                           object
#  113  found_name                    object
#  114  snippet                       object
#  115  full_result                   object
#  116  ein                           float64
#  117  cluster_lng                   float64
#  118  cluster_lat                   float64
#  119  cluster_ind                   float64
#  120  cluster_ngroup                float64
# dtypes: float64(30), int64(24), object(67)
# memory usage: 153.3+ KB

# %%
# note: people table combines tax info and BMF ICO
# need to decide on structure

'p_org_id', 'ICO', 'NAME', 'EIN', 'ntee_cat'

PersonNm', 'TitleTxt', 'IndividualTrusteeOrDirectorInd', 'OfficerInd'

# %% [markdown]
# # Extract ICO names

# %%
# create a dataframe that starts with ICOs

filt = np_local_df['ICO'].notna()
ico_df = np_local_df[filt][['p_org_id', 'ICO', 'NAME', 'EIN', 'ntee_cat' ]]

display(ico_df)
# np_local_df
# Out:
#      p_org_id                                  ICO  \
# 2       49916                      % TINA CAVALIER
# 3       85879                      % SUNY CORTLAND
# 4      119027                        % STEVEN NANN
# 5       36701                    % RICHARD NAUSEEF
# 6       61771                % PATTI W FITZPATRICK
# 7       42029                       % SUE CONNELLY
# 8       48184                   % JENNIFER SCHULTZ
# 10      36518                         % ERIKA DEAN
# 11     115772        % BARRY PRIMARY PTO TREASURER
# 13      73252                               % NONE
# 15      60464          % MATTHEW R NEUMAN ATTORNEY
# 16      54951                       % JEFF FAHERTY
# 17     114554                   % TRAVIS MACDOWELL
# 18      44398                        % MARK PIERCE
# 19      49052                      % JANICE HINMAN
# 20      92726                     % MENACHEM HECHT
# 25      40784                    % DONNA M RAYMOND
# 26      52740                     % LAURIE DUTCHER
# 27      43002                 % NICOLE KOEKEBACKER
# 28      44725                     % ADAM MCCRACKEN
# 29      52992            % C/O CORTLAND COUNTY AAA
# 32      68742                       % DEBORAH KING
# 35      40572                            % THURLOW
# 36      38505                      % SUNY CORTLAND
# 40      76821                      % MICHAEL WELLS
# 41      47554                   % JAMES P NUNCIATO
# 48      42170                        % KAREN NIDAY
# 50      73722                        % KAREN NIDAY
# 53     105510                      % SUJATA GIBSON
# 61      78531      % CORTLAND ENLARGED CITY SCHOOL
# 62      41604                         % NICK KLINE
# 64      85551                     % MARY E LEONARD
# 65      51769                      % MICHELE SISTO
# 66      62798                        % GINA SIKORA
# 68      85601  % C/O CORTLAND ENLARGED SCHOOL DIST
# 69      48247                     % MACHELL PHELPS
# 71     105037                        % JOHN ZELSON
# 73      46612                      % JANET FRIFFEN
# 75      86760                       % MARTIN LEWIS
# 77     110354                        % CLINT MORSE
# 80      88067                        % TERI H WOOD
# 81        949                    % CAROL WHITMARSH
# 85     104524                      % MATTHEW YOUNG
# 86      59428                      % PATRICIA HESS
# 87        449                   % JASON C TRABUCCO
# 88      35995                       % WADE A CALER
# 89      75520                      % KRISTIN BEARD
# 90      94574                   % ELIZABETH M COLE
# 92      39519                     % LINDA BATSFORD
# 95      57017                % MARILYN VAN DENBURG
# 96      38633              % AMY DERITO -TREASURER
# 97      36287                      % MICHELE SISTO
# 98      50490                       % C-O PAT LANG
# 100     44075                   % CHRISTOPHER GUAY
# 101     86457                % CHRISTINE L WIDDALL
# 103     36771                        % DAVID BLOCK
# 105    108324                       % DALE E DAVIS
# 106     59588                        % BARRY SANDS
# 107     75260                   % MICHAEL PETRELLA
# 108     42363                    % PATRICIA ROIGER
# 109     55622                    % LENORE SCHWAGER
# 112     60788                      % STEVE WOODARD
# 113    107472                        % NICOLE DAVI
# 116    111894                      % EDWARD M TOTH
# 119     70345                       % WALT DETREUX
# 120     65668                    % SUZANNA DILLION
# 122     69321                     % PAUL J COMFORT
# 123     69327                     % PAUL J COMFORT
# 125     54158  % KALEB WILSON AMERICA CREDIT UNION
# 126     34198                        % JOHN TUCKER
# 127     91150                     % STEPHEN C COYE
# 128     59265                   % SHIRLEY RANDOLPH
# 130     46554                      % LESLIE EASTON
# 131     47424                       % EUGENIA CUTE
# 134     35993                     % CLUB PRESIDENT
# 135     59403                       % BRUCE D KING
# 137    114354                    % RUSSELL PAULSEN
# 138     44509                   % RICHARD J ELLIOT
# 139     39680                       % NANCY WILSON
# 140     40967                     % GIANNA BRENNAN
# 141      1285                 % STEPHANIE DENSMORE
# 142     84028                    % THOMAS MARRETTA
# 144     48657               % DBA CORTLAND CHAPTER
# 145     99560                  % DAVID C ROLLINSON
# 146     42886                        % JIM DEMPSEY
# 154                          VIRGIL HISTORICAL SOCIETY  161442517
# 155                              WARRIORS OF THE CROSS  472550038
# 156                     WESTERN NEW YORK OFFROAD ASSOC  161560250
# 161                                ZONTA INTERNATIONAL  161305817
#
#                                               ntee_cat
# 2    (Q) International, Foreign Affairs & National ...
# 3                                              no_NTEE
# 4                                              no_NTEE
# 5                                              no_NTEE
# 6                                              no_NTEE
# 7                                              no_NTEE
# 8                                   (P) Human Services
# 10                                       (B) Education
# 11                                       (B) Education
# 13                                (X) Religion-Related
# 15                      (A) Arts, Culture & Humanities
# 16                                             no_NTEE
# 17                             (N) Recreation & Sports
# 18                                     (C) Environment
# 19                                  (D) Animal-Related
# 20                                (X) Religion-Related
# 25                                             no_NTEE
# 26                                             no_NTEE
# 27                                             no_NTEE
# 28                                             no_NTEE
# 29                                             no_NTEE
# 32                                  (P) Human Services
# 35                                  (P) Human Services
# 36                                             no_NTEE
# 40       (S) Community Improvement & Capacity Building
# 41   (T) Philanthropy, Voluntarism & Grantmaking Fo...
# 48       (S) Community Improvement & Capacity Building
# 50       (S) Community Improvement & Capacity Building
# 53       (S) Community Improvement & Capacity Building
# 61                                       (B) Education
# 62                                       (B) Education
# 64                      (A) Arts, Culture & Humanities
# 65                                     (E) Health Care
# 66                      (A) Arts, Culture & Humanities
# 68   (T) Philanthropy, Voluntarism & Grantmaking Fo...
# 69       (S) Community Improvement & Capacity Building
# 71                                      (J) Employment
# 73                                             no_NTEE
# 75                                      (J) Employment
# 77                             (N) Recreation & Sports
# 80                       (W) Public & Societal Benefit
# 81                                             no_NTEE
# 85                                  (D) Animal-Related
# 86                                             no_NTEE
# 87                                             no_NTEE
# 88                                             no_NTEE
# 89             (F) Mental Health & Crisis Intervention
# 90                       (W) Public & Societal Benefit
# 92                                             no_NTEE
# 95                                             no_NTEE
# 96                             (N) Recreation & Sports
# 97                                     (E) Health Care
# 98                               (O) Youth Development
# 100                            (N) Recreation & Sports
# 101                                      (B) Education
# 103                                            no_NTEE
# 105                                 (P) Human Services
# 106                            (N) Recreation & Sports
# 107                                            no_NTEE
# 108                                            no_NTEE
# 109                                            no_NTEE
# 112                                            no_NTEE
# 113                              (O) Youth Development
# 116                                    (C) Environment
# 119                                            no_NTEE
# 120                                      (B) Education
# 122                                            no_NTEE
# 123                                            no_NTEE
# 125                                            no_NTEE
# 126                     (A) Arts, Culture & Humanities
# 127                                      (B) Education
# 128                                            no_NTEE
# 130                                            no_NTEE
# 131                                 (D) Animal-Related
# 134                                            no_NTEE
# 135                                            no_NTEE
# 137      (S) Community Improvement & Capacity Building
# 138                                    (E) Health Care
# 139                                      (B) Education
# 140                                            no_NTEE
# 141                                        (Z) Unknown
# 142                               (X) Religion-Related
# 144                                            no_NTEE
# 145                                            no_NTEE
# 146                            (N) Recreation & Sports
# 148                                            no_NTEE
# 149                                    (E) Health Care
# 150                                            no_NTEE
# 151                            (N) Recreation & Sports
# 154                     (A) Arts, Culture & Humanities
# 155                      (W) Public & Societal Benefit
# 156                            (N) Recreation & Sports
# 161                                            no_NTEE

# %%
# prep ico for merge with other people

#ico_df.rename(columns={'ICO': 'PersonNm'}, inplace=True)

#ico_df['PersonNm'] = ico_df['PersonNm'].str.replace('% ', '')
ico_df['TitleTxt'] = 'ICO'

display(ico_df)
# Out:
#      p_org_id                           PersonNm  \
# 2       49916                      TINA CAVALIER
# 3       85879                      SUNY CORTLAND
# 4      119027                        STEVEN NANN
# 5       36701                    RICHARD NAUSEEF
# 6       61771                PATTI W FITZPATRICK
# 7       42029                       SUE CONNELLY
# 8       48184                   JENNIFER SCHULTZ
# 10      36518                         ERIKA DEAN
# 11     115772        BARRY PRIMARY PTO TREASURER
# 13      73252                               NONE
# 15      60464          MATTHEW R NEUMAN ATTORNEY
# 16      54951                       JEFF FAHERTY
# 17     114554                   TRAVIS MACDOWELL
# 18      44398                        MARK PIERCE
# 19      49052                      JANICE HINMAN
# 20      92726                     MENACHEM HECHT
# 25      40784                    DONNA M RAYMOND
# 26      52740                     LAURIE DUTCHER
# 27      43002                 NICOLE KOEKEBACKER
# 28      44725                     ADAM MCCRACKEN
# 29      52992            C/O CORTLAND COUNTY AAA
# 32      68742                       DEBORAH KING
# 35      40572                            THURLOW
# 36      38505                      SUNY CORTLAND
# 40      76821                      MICHAEL WELLS
# 41      47554                   JAMES P NUNCIATO
# 48      42170                        KAREN NIDAY
# 50      73722                        KAREN NIDAY
# 53     105510                      SUJATA GIBSON
# 61      78531      CORTLAND ENLARGED CITY SCHOOL
# 62      41604                         NICK KLINE
# 64      85551                     MARY E LEONARD
# 65      51769                      MICHELE SISTO
# 66      62798                        GINA SIKORA
# 68      85601  C/O CORTLAND ENLARGED SCHOOL DIST
# 69      48247                     MACHELL PHELPS
# 71     105037                        JOHN ZELSON
# 73      46612                      JANET FRIFFEN
# 75      86760                       MARTIN LEWIS
# 77     110354                        CLINT MORSE
# 80      88067                        TERI H WOOD
# 81        949                    CAROL WHITMARSH
# 85     104524                      MATTHEW YOUNG
# 86      59428                      PATRICIA HESS
# 87        449                   JASON C TRABUCCO
# 88      35995                       WADE A CALER
# 89      75520                      KRISTIN BEARD
# 90      94574                   ELIZABETH M COLE
# 92      39519                     LINDA BATSFORD
# 95      57017                MARILYN VAN DENBURG
# 96      38633              AMY DERITO -TREASURER
# 97      36287                      MICHELE SISTO
# 98      50490                       C-O PAT LANG
# 100     44075                   CHRISTOPHER GUAY
# 101     86457                CHRISTINE L WIDDALL
# 103     36771                        DAVID BLOCK
# 105    108324                       DALE E DAVIS
# 106     59588                        BARRY SANDS
# 107     75260                   MICHAEL PETRELLA
# 108     42363                    PATRICIA ROIGER
# 109     55622                    LENORE SCHWAGER
# 112     60788                      STEVE WOODARD
# 113    107472                        NICOLE DAVI
# 116    111894                      EDWARD M TOTH
# 119     70345                       WALT DETREUX
# 120     65668                    SUZANNA DILLION
# 122     69321                     PAUL J COMFORT
# 123     69327                     PAUL J COMFORT
# 125     54158  KALEB WILSON AMERICA CREDIT UNION
# 126     34198                        JOHN TUCKER
# 127     91150                     STEPHEN C COYE
# 128     59265                   SHIRLEY RANDOLPH
# 109                                            no_NTEE      ICO
# 112                                            no_NTEE      ICO
# 113                              (O) Youth Development      ICO
# 116                                    (C) Environment      ICO
# 119                                            no_NTEE      ICO
# 120                                      (B) Education      ICO
# 122                                            no_NTEE      ICO
# 123                                            no_NTEE      ICO
# 125                                            no_NTEE      ICO
# 126                     (A) Arts, Culture & Humanities      ICO
# 127                                      (B) Education      ICO
# 128                                            no_NTEE      ICO
# 130                                            no_NTEE      ICO
# 131                                 (D) Animal-Related      ICO
# 134                                            no_NTEE      ICO
# 135                                            no_NTEE      ICO
# 137      (S) Community Improvement & Capacity Building      ICO
# 138                                    (E) Health Care      ICO
# 139                                      (B) Education      ICO
# 140                                            no_NTEE      ICO
# 141                                        (Z) Unknown      ICO
# 142                               (X) Religion-Related      ICO
# 144                                            no_NTEE      ICO
# 145                                            no_NTEE      ICO
# 146                            (N) Recreation & Sports      ICO
# 148                                            no_NTEE      ICO
# 149                                    (E) Health Care      ICO
# 150                                            no_NTEE      ICO
# 151                            (N) Recreation & Sports      ICO
# 154                     (A) Arts, Culture & Humanities      ICO
# 155                      (W) Public & Societal Benefit      ICO
# 156                            (N) Recreation & Sports      ICO
# 161                                            no_NTEE      ICO

# %% [markdown]
# # Extract people XML snippets from IRS Taxes.

# %%
# nonprofits that have people listed in json-ish column
filt = np_local_df['people'].notna()
people_df = np_local_df[filt][['p_org_id', 'people', 'NAME', 'EIN', 'ntee_cat' ]]

# %%
# Reading snippet as json
# but should have tried xmltodict, first

# simple-minded massage seemed to work, so leaving for now.

# Simple-minded:  to replace single quotes with double quotes
# but some names have single quotes (O'Connell) so

# but when last name ends with O it'll be followed by comma
#filt= people_df['people'].str.contains('O\',')
#display(people_df[filt])

# here's an over simple fix
# first deal with people with names ending in O, marker <end>
people_df['people'] = people_df['people'].str.replace('O\',', 'O<end>, ')

# then get the actual O' names
people_df['people'] = people_df['people'].str.replace('O\'', 'O ')

# then take out marker and add sq back
people_df['people'] = people_df['people'].str.replace('<end>', '\'')

# note: there is a routine in streamlit app that uses findall
# but cut'n paste didn't work and  trying this fast

# %%
display(people2_df)
# Out:
#            PersonNm            TitleTxt IndividualTrusteeOrDirectorInd  \
# 0   RICHARD NAUSEEF  1ST VICE TREASURER                             na
# 1  LYLE BUDDENHAGEN            3RD VICE                             na
# 2      KENNETH BUSH            ADJUTANT                             na
# 3   THOMAS THOMPSON           COMMANDER                             na
# 4     DOUGLAS BROWN            2ND VICE                             na
#
#   OfficerInd
# 0          X
# 1          X
# 2          X
# 3          X
# 4          X

# %%
# iterates dataframe to extract people from json-ish

# previous cell fixes the name problem
# now simple replacement of single quotes for double to make valid json
# Note: dict to dataframe tools would prob be better than iteration

people2_df = pd.DataFrame(columns=['p_org_id', 'NAME', 'EIN', 'ntee_cat',
                                   'PersonNm', 'TitleTxt', 'IndividualTrusteeOrDirectorInd',
                                   'OfficerInd'])

for index, row in people_df.iterrows():
  # print("\n", index, row['people'])
  person_list = []
  org_common_list = []

  # get basic columns that will get added to every person
  org_common_list = [row['p_org_id'], row['NAME'], row['EIN'], row['ntee_cat']]
  #row['p_org_id'], row['people'], row['NAME'], row['EIN'], row['ntee_cat']


  # used simple fix above for names with single quote O'GORMAN,

  # now, simple general attempt to just replace single quotes
  ppl = row['people'].replace("\'", "\"")

  try:
    ppl_dict = json.loads(ppl)   # IRS Tax I guess is a list of dicts, but single quoted
  except:
    print (ppl)

  for each_row  in ppl_dict:
    person_list = []
    for each_col in ['PersonNm', 'TitleTxt', 'IndividualTrusteeOrDirectorInd', 'OfficerInd']:
      # different IRS form have different tags
      if each_col in each_row:
        try:
          person_list.append(each_row[each_col])
        except:
          print ("hmm", each_row)
      else:
        person_list.append("na")

    list_to_add = org_common_list + person_list
    person_list = []

    # add list to end of dataframe
    try:
      people2_df.loc[len(people2_df)] = list_to_add
    except:
      print ("erg", list_to_add)
# Out:
# hmm PersonNm
# erg [73252, 'BILLY BIMBA GLOBAL MINISTRIES INC', 454495541, '(X) Religion-Related', 'na', 'na', 'na']
# hmm TitleTxt
# erg [73252, 'BILLY BIMBA GLOBAL MINISTRIES INC', 454495541, '(X) Religion-Related', 'na', 'na', 'na']
# hmm PersonNm
# erg [37344, 'GRANGE PATRONS OF HUSBANDRY NEW YORK STATE GRANGE INC', 160725792, 'no_NTEE', 'na', 'na', 'na']
# hmm TitleTxt
# erg [37344, 'GRANGE PATRONS OF HUSBANDRY NEW YORK STATE GRANGE INC', 160725792, 'no_NTEE', 'na', 'na', 'na']

# %% [markdown]
# # Combine all people

# %%
all_people_df = pd.concat([ico_df, people2_df])
display(all_people_df)
# Out:
#      p_org_id             PersonNm                                NAME  \
# 2       49916        TINA CAVALIER                    AFRICA READS INC
# 3       85879        SUNY CORTLAND                     ALPHA PHI OMEGA
# 4      119027          STEVEN NANN     AMERICAN FEDERATION OF TEACHERS
# 5       36701      RICHARD NAUSEEF                     AMERICAN LEGION
# 6       61771  PATTI W FITZPATRICK           AMERICAN LEGION AUXILIARY
# ..        ...                  ...                                 ...
# 814     36391       MIKE STAPLETON  YOUNG WOMENS CHRISTIAN ASSOCIATION
# 815     36391           ANGELA LOH  YOUNG WOMENS CHRISTIAN ASSOCIATION
# 816     36391      JOHN WHITTLETON  YOUNG WOMENS CHRISTIAN ASSOCIATION
# 817     36391  SUE SHERMAN-BROYLES  YOUNG WOMENS CHRISTIAN ASSOCIATION
# 818     36391         MERLE MCKOWN  YOUNG WOMENS CHRISTIAN ASSOCIATION
#
#            EIN                                           ntee_cat  \
# 2    204703107  (Q) International, Foreign Affairs & National ...
# 3    593837821                                            no_NTEE
# 4    990725348                                            no_NTEE
# 5    150610966                                            no_NTEE
# 6    263340217                                            no_NTEE
# ..         ...                                                ...
# 814  150536617                                 (P) Human Services
# 815  150536617                                 (P) Human Services
# 816  150536617                                 (P) Human Services
# 817  150536617                                 (P) Human Services
# 818  150536617                                 (P) Human Services
#
#             TitleTxt IndividualTrusteeOrDirectorInd OfficerInd
# 2                ICO                            NaN        NaN
# 3                ICO                            NaN        NaN
# 4                ICO                            NaN        NaN
# 5                ICO                            NaN        NaN
# 6                ICO                            NaN        NaN
# ..               ...                            ...        ...
# 814  Trustee-Treasur                              X          X
# 815     Trustee-PRES                              X          X
# 816          Trustee                              X         na
# 817      TRUSTEE SEC                              X          X
# 818          Trustee                              X         na
#
# [912 rows x 8 columns]

# %% [markdown]
# # Data Checks

# %%
# TODO: Research these people who had errors

hmm PersonNm
erg [73252, 'BILLY BIMBA GLOBAL MINISTRIES INC', 454495541, '(X) Religion-Related', 'na', 'na', 'na']
hmm TitleTxt
erg [73252, 'BILLY BIMBA GLOBAL MINISTRIES INC', 454495541, '(X) Religion-Related', 'na', 'na', 'na']
hmm PersonNm
erg [37344, 'GRANGE PATRONS OF HUSBANDRY NEW YORK STATE GRANGE INC', 160725792, 'no_NTEE', 'na', 'na', 'na']
hmm TitleTxt
erg [37344, 'GRANGE PATRONS OF HUSBANDRY NEW YORK STATE GRANGE INC', 160725792, 'no_NTEE', 'na', 'na', 'na']

# %%
# Name Variations
# TODO: Add fuzzy name check

all_people_df = pd.read_csv(data_dir + 'all_people.csv')
display(all_people_df)
# Out:
#      Unnamed: 0  p_org_id          PersonNm  \
# 0           779     36375     ADAM CLIFFORD
# 1           771     76383     ADAM CLIFFORD
# 2            28     44725    ADAM MCCRACKEN
# 3           243     38548    ADELE FETTERLY
# 4           797     36391    ADRIANNE TRAUB
# ..          ...       ...               ...
# 884         657     56342     WILLIAM MCKEE
# 885         604     38243    WILLIAM MURPHY
# 886         715     39411  WILLIAM WEISMORE
# 887         472     35994       Warren Eddy
# 888         585     36771   William F Young
#
#                                                   NAME        EIN  \
# 0            YOUNG MENS CHRISTIAN ASSOCIATION CORTLAND  150533570
# 1                      YMCA OF CORTLAND PROPERTIES INC  463376307
# 2                  CIVIL SERVICE EMPLOYEES ASSOCIATION  161613155
# 3                   CORTLAND COUNTY BOARD REALTORS INC  160987063
# 4                   YOUNG WOMENS CHRISTIAN ASSOCIATION  150536617
# ..                                                 ...        ...
# 884                    NATIONAL ACADEMY OF ARBITRATORS  237126791
# 885                              J M MURRAY CENTER INC  160919050
# 886            STATEWIDE COUNTRY MUSIC ASSOCIATION INC  161132390
# 887                            CORTLAND RURAL CEMETERY  150279170
# 888  INTERNATIONAL UNION UNITED AUTO AEROSPACE & AG...  150623052
#
#                            ntee_cat                TitleTxt  \
# 0                (P) Human Services  BOARD MEMBER/PRESIDENT
# 1                (P) Human Services               PRESIDENT
# 2                           no_NTEE                     ICO
# 3                           no_NTEE               TREASURER
# 4                (P) Human Services            BOARD MEMBER
# ..                              ...                     ...
# 884                         no_NTEE         PRESIDENT-ELECT
# 885                  (J) Employment                DIRECTOR
# 886  (A) Arts, Culture & Humanities     MEMBERSHIP DIRECTOR
# 887                         no_NTEE                 Trustee
# 888                         no_NTEE               President
#
#     IndividualTrusteeOrDirectorInd OfficerInd
# 0                                X          X
# 1                               na         na
# 2                              NaN        NaN
# 3                               na         na
# 4                                X         na
# ..                             ...        ...
# 884                              X          X
# 885                              X         na
# 886                              X         na
# 887                              X         na
# 888                             na          X
#
# [889 rows x 9 columns]

# %%
display(people2_df)
#display(ico_df)
#people2_df.info()
# Out:
#      p_org_id                                       NAME        EIN  \
# 0       18383  1890 HOUSE MUSEUM AND CENTER FOR THE ARTS  132951986
# 1       18383  1890 HOUSE MUSEUM AND CENTER FOR THE ARTS  132951986
# 2       18383  1890 HOUSE MUSEUM AND CENTER FOR THE ARTS  132951986
# 3       18383  1890 HOUSE MUSEUM AND CENTER FOR THE ARTS  132951986
# 4       18383  1890 HOUSE MUSEUM AND CENTER FOR THE ARTS  132951986
# ..        ...                                        ...        ...
# 814     36391         YOUNG WOMENS CHRISTIAN ASSOCIATION  150536617
# 815     36391         YOUNG WOMENS CHRISTIAN ASSOCIATION  150536617
# 816     36391         YOUNG WOMENS CHRISTIAN ASSOCIATION  150536617
# 817     36391         YOUNG WOMENS CHRISTIAN ASSOCIATION  150536617
# 818     36391         YOUNG WOMENS CHRISTIAN ASSOCIATION  150536617
#
#                            ntee_cat             PersonNm         TitleTxt  \
# 0    (A) Arts, Culture & Humanities         TERRY MINGLE        BD MEMBER
# 1    (A) Arts, Culture & Humanities      MARK HARRINGTON        BD MEMBER
# 2    (A) Arts, Culture & Humanities         JERRY WILCOX        BD MEMBER
# 3    (A) Arts, Culture & Humanities          JANE HUNTER        BD MEMBER
# 4    (A) Arts, Culture & Humanities    NICOLE HOLLENBACK        BD MEMBER
# ..                              ...                  ...              ...
# 814              (P) Human Services       MIKE STAPLETON  Trustee-Treasur
# 815              (P) Human Services           ANGELA LOH     Trustee-PRES
# 816              (P) Human Services      JOHN WHITTLETON          Trustee
# 817              (P) Human Services  SUE SHERMAN-BROYLES      TRUSTEE SEC
# 818              (P) Human Services         MERLE MCKOWN          Trustee
#
#     IndividualTrusteeOrDirectorInd OfficerInd
# 0                                X         na
# 1                                X         na
# 2                                X         na
# 3                                X         na
# 4                                X         na
# ..                             ...        ...
# 814                              X          X
# 815                              X          X
# 816                              X         na
# 817                              X          X
# 818                              X         na
#
# [819 rows x 8 columns]

# %% [markdown]
# # Save the people!

# %%
#all_people_df['PersonNm'].value_counts()

# all_people_dfPersonNm.groupby(all_people_df['PersonNm']).count().sort_values(ascending=False)

filt = all_people_df['PersonNm'] != 'na'
# all_people_df = all_people_df[filt]

all_people_df[filt].sort_values('PersonNm').to_csv(data_dir + 'all_people.csv')

# %% [markdown]
# # Test collections for visualization

# %%
all_people_df = pd.read_csv(data_dir + 'all_people.csv')

# %%
display(all_people_df)
# Out:
#      Unnamed: 0  p_org_id          PersonNm  \
# 0           779     36375     ADAM CLIFFORD
# 1           771     76383     ADAM CLIFFORD
# 2            28     44725    ADAM MCCRACKEN
# 3           243     38548    ADELE FETTERLY
# 4           797     36391    ADRIANNE TRAUB
# ..          ...       ...               ...
# 884         657     56342     WILLIAM MCKEE
# 885         604     38243    WILLIAM MURPHY
# 886         715     39411  WILLIAM WEISMORE
# 887         472     35994       Warren Eddy
# 888         585     36771   William F Young
#
#                                                   NAME        EIN  \
# 0            YOUNG MENS CHRISTIAN ASSOCIATION CORTLAND  150533570
# 1                      YMCA OF CORTLAND PROPERTIES INC  463376307
# 2                  CIVIL SERVICE EMPLOYEES ASSOCIATION  161613155
# 3                   CORTLAND COUNTY BOARD REALTORS INC  160987063
# 4                   YOUNG WOMENS CHRISTIAN ASSOCIATION  150536617
# ..                                                 ...        ...
# 884                    NATIONAL ACADEMY OF ARBITRATORS  237126791
# 885                              J M MURRAY CENTER INC  160919050
# 886            STATEWIDE COUNTRY MUSIC ASSOCIATION INC  161132390
# 887                            CORTLAND RURAL CEMETERY  150279170
# 888  INTERNATIONAL UNION UNITED AUTO AEROSPACE & AG...  150623052
#
#                            ntee_cat                TitleTxt  \
# 0                (P) Human Services  BOARD MEMBER/PRESIDENT
# 1                (P) Human Services               PRESIDENT
# 2                           no_NTEE                     ICO
# 3                           no_NTEE               TREASURER
# 4                (P) Human Services            BOARD MEMBER
# ..                              ...                     ...
# 884                         no_NTEE         PRESIDENT-ELECT
# 885                  (J) Employment                DIRECTOR
# 886  (A) Arts, Culture & Humanities     MEMBERSHIP DIRECTOR
# 887                         no_NTEE                 Trustee
# 888                         no_NTEE               President
#
#     IndividualTrusteeOrDirectorInd OfficerInd
# 0                                X          X
# 1                               na         na
# 2                              NaN        NaN
# 3                               na         na
# 4                                X         na
# ..                             ...        ...
# 884                              X          X
# 885                              X         na
# 886                              X         na
# 887                              X         na
# 888                             na          X
#
# [889 rows x 9 columns]

# %%
# people with more than one connection
all_people_df[all_people_df['PersonNm'].groupby(all_people_df['PersonNm']).transform('size')>1]
# Out:
#      Unnamed: 0  p_org_id            PersonNm  \
# 0           779     36375       ADAM CLIFFORD
# 1           771     76383       ADAM CLIFFORD
# 8           737     42886       ALICE STARMER
# 9           321     42170       ALICE STARMER
# 25          359     54486  ANDREA PIEDIGROSSI
# ..          ...       ...                 ...
# 846         766     76383          TIM HERMAN
# 859          17    114554    TRAVIS MACDOWELL
# 860          87    114554    TRAVIS MACDOWELL
# 875         694     70345       WALT DE TREUX
# 876         661     56342       WALT DE TREUX
#
#                                                   NAME        EIN  \
# 0            YOUNG MENS CHRISTIAN ASSOCIATION CORTLAND  150533570
# 1                      YMCA OF CORTLAND PROPERTIES INC  463376307
# 8                   THE GREAT CORTLAND PUMPKINFEST INC  161506254
# 9     CORTLAND COUNTY CONVENTION & VISITORS BUREAU INC  161454737
# 25        CORTLAND COUNTY YOUTH SOCCER ASSOCIATION INC  223320358
# ..                                                 ...        ...
# 846                    YMCA OF CORTLAND PROPERTIES INC  463376307
# 859                 CENTRAL NEW YORK ACTION SPORTS INC  920791511
# 860                 CENTRAL NEW YORK ACTION SPORTS INC  920791511
# 875  NATIONAL ACADEMY OF ARBITRATORS RESEARCH & EDU...  382613043
# 876                    NATIONAL ACADEMY OF ARBITRATORS  237126791
#
#                                           ntee_cat                TitleTxt  \
# 0                               (P) Human Services  BOARD MEMBER/PRESIDENT
# 1                               (P) Human Services               PRESIDENT
# 8                          (N) Recreation & Sports          VICE PRESIDENT
# 9    (S) Community Improvement & Capacity Building            BOARD MEMBER
# 25                                         no_NTEE         DIRECTOR OF REC
# ..                                             ...                     ...
# 846                             (P) Human Services               TREASURER
# 859                        (N) Recreation & Sports                     ICO
# 860                        (N) Recreation & Sports               PRESIDENT
# 875                                        no_NTEE     SECRETARY-TREASURER
# 876                                        no_NTEE     SECRETARY/TREASURER
#
#     IndividualTrusteeOrDirectorInd OfficerInd
# 0                                X          X
# 1                               na         na
# 8                                X          X
# 9                                X         na
# 25                              na         na
# ..                             ...        ...
# 846                             na         na
# 859                            NaN        NaN
# 860                              X          X
# 875                              X          X
# 876                              X          X
#
# [145 rows x 9 columns]

# %% [markdown]
# # Fodder

# %%
# this used in streamlit to fix O' names
import re

for index, row in people_df.iterrows():
  print ("----------- print people -------------")
  print(row['people'])
  print ("----------- end people -------------")

  # ppl = json.loads(row['people'])
  # ppl = json.loads(json.dumps(row['people']))
  ppl = json.loads(row['people'].replace("'", "\""))

  #print (json.loads(ppl))

  # for r in row['people']:
  #  print (r)

  # ppl = row['people'].replace("\'", "\"")
  #  print(ppl)



  if index == 2:
    break

   ###

  if isinstance(ppl, str):

      quoted_stuff = re.findall('"([^"]*)"', ppl)
      # st.write (quoted_stuff)
      for t in quoted_stuff:
          fix_t = t.replace("'", " ") # KATHLEEN O CONNELL
          # ok, try this way
          ppl = ppl.replace(t, fix_t) # replace name with no sq

      # after taking sq from any quoted string
      # then replace dq with single quote
      ppl = ppl.replace('"', "'")   # with quoted handled, make all sq
      ppl =  ppl.replace("'", '"')  # replace sq with dq for json

      # st.text (ppl)
      ppl_dict = json.loads(ppl)
      # return {'status' : 'no people'}
      # return ppl_dict
      pprint.pprint(ppl_dict)

  else:
      print ( 'no people')

  ###
# Out:
# ----------- print people -------------
# [{'PersonNm': 'TERRY MINGLE', 'TitleTxt': 'BD MEMBER', 'AverageHoursPerWeekRt': '1.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'MARK HARRINGTON', 'TitleTxt': 'BD MEMBER', 'AverageHoursPerWeekRt': '1.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'JERRY WILCOX', 'TitleTxt': 'BD MEMBER', 'AverageHoursPerWeekRt': '1.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'JANE HUNTER', 'TitleTxt': 'BD MEMBER', 'AverageHoursPerWeekRt': '1.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'NICOLE HOLLENBACK', 'TitleTxt': 'BD MEMBER', 'AverageHoursPerWeekRt': '1.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'SCOTT GAY', 'TitleTxt': 'BD MEMBER', 'AverageHoursPerWeekRt': '1.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'MARISA GAY-ZOGG', 'TitleTxt': 'BD MEMBER', 'AverageHoursPerWeekRt': '1.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'MARGARET RYAN', 'TitleTxt': 'BD MEMBER', 'AverageHoursPerWeekRt': '1.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'LEE BENSON', 'TitleTxt': 'VICE PRESIDENT', 'AverageHoursPerWeekRt': '2.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'KRISTEN EVANGELISTA', 'TitleTxt': 'BD MEMBER', 'AverageHoursPerWeekRt': '1.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'STEVE RYAN', 'TitleTxt': 'SECRETARY', 'AverageHoursPerWeekRt': '2.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'OfficerInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'DAN HORN', 'TitleTxt': 'BD MEMBER', 'AverageHoursPerWeekRt': '1.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'OfficerInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'ANNETTE BENSON', 'TitleTxt': 'TREASURER', 'AverageHoursPerWeekRt': '2.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'OfficerInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'STACEY WILLIAM', 'TitleTxt': 'PRESIDENT', 'AverageHoursPerWeekRt': '2.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'OfficerInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}]
# ----------- end people -------------
# no people
# ----------- print people -------------
# [{'PersonNm': 'Alexandra Mikowski', 'TitleTxt': 'Executive Director', 'AverageHoursPerWeekRt': '45.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'OfficerInd': 'X', 'HighestCompensatedEmployeeInd': 'X', 'ReportableCompFromOrgAmt': '54897', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'Linda Stock', 'TitleTxt': 'Board Member', 'AverageHoursPerWeekRt': '2.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'Christina Taranto', 'TitleTxt': 'Board Member', 'AverageHoursPerWeekRt': '2.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'Janet Oechsle', 'TitleTxt': 'Board Member', 'AverageHoursPerWeekRt': '2.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'Barbara Morris', 'TitleTxt': 'Board Member', 'AverageHoursPerWeekRt': '1.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'Michael Wells', 'TitleTxt': 'Board Member', 'AverageHoursPerWeekRt': '40.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'Melissa Kiser', 'TitleTxt': 'Board Member', 'AverageHoursPerWeekRt': '2.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'Dorothy Dumond', 'TitleTxt': 'Board Member', 'AverageHoursPerWeekRt': '2.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'Conni Bentley', 'TitleTxt': 'Board Member', 'AverageHoursPerWeekRt': '5.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'Lisa Pizzola', 'TitleTxt': 'Board Member', 'AverageHoursPerWeekRt': '2.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'Christina Carden', 'TitleTxt': 'Board Secretary', 'AverageHoursPerWeekRt': '2.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'OfficerInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'Laura Eaton', 'TitleTxt': 'Board Vice Chair', 'AverageHoursPerWeekRt': '2.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'OfficerInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'Lawrence Woolheater', 'TitleTxt': 'Board Chair', 'AverageHoursPerWeekRt': '2.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'OfficerInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'Kathleen Barnes', 'TitleTxt': 'Board Treasurer', 'AverageHoursPerWeekRt': '2.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'OfficerInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}]
# ----------- end people -------------
# no people
# ----------- print people -------------
# [{'PersonNm': 'RICHARD NAUSEEF', 'TitleTxt': '1ST VICE TREASURER', 'AverageHoursPerWeekRt': '10.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'OfficerInd': 'X', 'ReportableCompFromOrgAmt': '10225', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'LYLE BUDDENHAGEN', 'TitleTxt': '3RD VICE', 'AverageHoursPerWeekRt': '1.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'OfficerInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'KENNETH BUSH', 'TitleTxt': 'ADJUTANT', 'AverageHoursPerWeekRt': '1.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'OfficerInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'THOMAS THOMPSON', 'TitleTxt': 'COMMANDER', 'AverageHoursPerWeekRt': '1.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'OfficerInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'DOUGLAS BROWN', 'TitleTxt': '2ND VICE', 'AverageHoursPerWeekRt': '1.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'OfficerInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}]
# ----------- end people -------------
# no people
# ----------- print people -------------
# [{'PersonNm': "ROBERT O'GORMAN", 'AverageHoursPerWeekRt': '40.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'ReportableCompFromOrgAmt': '238493', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '21550'}, {'PersonNm': 'GARY WAINWRIGHT', 'TitleTxt': 'Director', 'AverageHoursPerWeekRt': '1.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'STET SCHANZE', 'TitleTxt': 'Director', 'AverageHoursPerWeekRt': '1.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'OfficerInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'JEFF KRITZER', 'TitleTxt': 'Past Chairman', 'AverageHoursPerWeekRt': '1.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'OfficerInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'DOUG BROWN', 'TitleTxt': 'Chairman', 'AverageHoursPerWeekRt': '1.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'OfficerInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'GARY DIANGELO', 'TitleTxt': 'Director', 'AverageHoursPerWeekRt': '1.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'ALLAN PAVLICK', 'TitleTxt': 'Director', 'AverageHoursPerWeekRt': '1.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}, {'PersonNm': 'BRIAN SPIKES', 'TitleTxt': 'Director', 'AverageHoursPerWeekRt': '1.00', 'AverageHoursPerWeekRltdOrgRt': '0.00', 'IndividualTrusteeOrDirectorInd': 'X', 'ReportableCompFromOrgAmt': '0', 'ReportableCompFromRltdOrgAmt': '0', 'OtherCompensationAmt': '0'}]
# ----------- end people -------------
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-40-6439e1d7717e> in <cell line: 4>()
#       9   # ppl = json.loads(row['people'])
#      10   # ppl = json.loads(json.dumps(row['people']))
# ---> 11   ppl = json.loads(row['people'].replace("'", "\""))
#      12
#      13   #print (json.loads(ppl))
#
# /usr/lib/python3.10/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# /usr/lib/python3.10/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /usr/lib/python3.10/json/decoder.py in raw_decode(self, s, idx)
#     351         """
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#     355             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting ',' delimiter: line 1 column 25 (char 24)
